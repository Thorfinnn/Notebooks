# %%
# !pip install lightautoml
# Out:
# ...
#      -------------------------------------- 416.4/416.4 kB 4.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 309.5/309.5 kB 3.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.9/14.9 MB 2.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 215.7/215.7 kB 1.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.0/1.0 MB 2.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 380.1/380.1 kB 2.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 101.2/101.2 MB 5.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.8/2.8 MB 6.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 47.1/47.1 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.7/14.7 MB 7.5 MB/s eta 0:00:00
# ...
